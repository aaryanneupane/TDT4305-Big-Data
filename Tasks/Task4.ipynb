# %% [markdown]
# #### Names of people in the group
#
# Please write the names of the people in your group in the next cell.

# %% [markdown]
# Anne Torgersen
#
# Aaryan Neupane

# %%
# Loading modules that we need
from pyspark.sql.session import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

# Add your imports below this line

# %%
# A helper function to load a table (stored in Parquet format) from DBFS as a Spark DataFrame 
def load_df(table_name: "name of the table to load") -> DataFrame:
    return spark.read.parquet(table_name)

users_df = load_df("/user/hive/warehouse/users")
posts_df = load_df("/user/hive/warehouse/posts")

# Uncomment if you need
# comments_df = load_df("/user/hive/warehouse/comments")
# badges_df = load_df("/user/hive/warehouse/badges")

# %% [markdown]
# ### The Problem: Mining the Interests of Experts

# %% [markdown]
# ##### User reputation

# %%
## Divide the needed data into a user reputation variable
users_df.createOrReplaceTempView("users")
query1 = '''
SELECT Id, Reputation
FROM users
'''
usr_rep = spark.sql(query1)
print(usr_rep.collect())
# Out:
# [Row(Id=-1, Reputation='1'), Row(Id=1, Reputation='101'), Row(Id=2, Reputation='101'), Row(Id=3, Reputation='101'), Row(Id=4, Reputation='101'), Row(Id=5, Reputation='215'), Row(Id=6, Reputation='101'), Row(Id=7, Reputation='101'), Row(Id=8, Reputation='101'), Row(Id=9, Reputation='1102'), Row(Id=10, Reputation='101'), Row(Id=11, Reputation='213'), Row(Id=12, Reputation='101'), Row(Id=14, Reputation='2782'), Row(Id=15, Reputation='101'), Row(Id=16, Reputation='1'), Row(Id=17, Reputation='236'), Row(Id=18, Reputation='101'), Row(Id=19, Reputation='101'), Row(Id=20, Reputation='101'), Row(Id=21, Reputation='5904'), Row(Id=22, Reputation='323'), Row(Id=23, Reputation='101'), Row(Id=24, Reputation='171'), Row(Id=25, Reputation='101'), Row(Id=26, Reputation='2952'), Row(Id=27, Reputation='101'), Row(Id=28, Reputation='101'), Row(Id=29, Reputation='101'), Row(Id=30, Reputation='101'), Row(Id=31, Reputation='1'), Row(Id=32, Reputation='101'), Row(Id=33, Reputation='101'), Row(Id=34, Reputation='173'), Row(Id=35, Reputation='101'), Row(Id=36, Reputation='325'), Row(Id=37, Reputation='105'), Row(Id=38, Reputation='101'), Row(Id=39, Reputation='101'), Row(Id=40, Reputation='1'), Row(Id=41, Reputation='101'), Row(Id=42, Reputation='1'), Row(Id=43, Reputation='101'), Row(Id=45, Reputation='101'), Row(Id=46, Reputation='101'), Row(Id=47, Reputation='101'), Row(Id=48, Reputation='101'), Row(Id=50, Reputation='101'), Row(Id=51, Reputation='176'), Row(Id=52, Reputation='146'), Row(Id=53, Reputation='404'), Row(Id=54, Reputation='1'), Row(Id=55, Reputation='101'), Row(Id=56, Reputation='1'), Row(Id=57, Reputation='101'), Row(Id=58, Reputation='1'), Row(Id=59, Reputation='986'), Row(Id=60, Reputation='101'), Row(Id=61, Reputation='101'), Row(Id=62, Reputation='654'), Row(Id=63, Reputation='283'), Row(Id=64, Reputation='75'), Row(Id=65, Reputation='101'), Row(Id=66, Reputation='403'), Row(Id=67, Reputation='101'), Row(Id=68, Reputation='101'), Row(Id=69, Reputation='101'), Row(Id=70, Reputation='181'), Row(Id=71, Reputation='203'), Row(Id=72, Reputation='101'), Row(Id=73, Reputation='1'), Row(Id=74, Reputation='1'), Row(Id=75, Reputation='721'), Row(Id=76, Reputation='101'), Row(Id=77, Reputation='121'), Row(Id=78, Reputation='101'), Row(Id=79, Reputation='101'), Row(Id=80, Reputation='101'), Row(Id=81, Reputation='1'), Row(Id=82, Reputation='549'), Row(Id=83, Reputation='101'), Row(Id=84, Reputation='3967'), Row(Id=85, Reputation='101'), Row(Id=86, Reputation='1'), Row(Id=87, Reputation='101'), Row(Id=88, Reputation='971'), Row(Id=90, Reputation='390'), Row(Id=91, Reputation='101'), Row(Id=92, Reputation='941'), Row(Id=93, Reputation='101'), Row(Id=94, Reputation='101'), Row(Id=95, Reputation='355'), Row(Id=96, Reputation='273'), Row(Id=97, Reputation='4832'), Row(Id=98, Reputation='123'), Row(Id=99, Reputation='101'), Row(Id=100, Reputation='101'), Row(Id=101, Reputation='101'), Row(Id=102, Reputation='151'), Row(Id=104, Reputation='259'), Row(Id=105, Reputation='101'), Row(Id=106, Reputation='190'), Row(Id=107, Reputation='101'), Row(Id=108, Reputation='3805'), Row(Id=110, Reputation='1'), Row(Id=111, Reputation='101'), Row(Id=112, Reputation='101'), Row(Id=113, Reputation='443'), Row(Id=114, Reputation='101'), Row(Id=115, Reputation='579'), Row(Id=116, Reputation='367'), Row(Id=117, Reputation='1'), Row(Id=118, Reputation='634'), Row(Id=119, Reputation='281'), Row(Id=120, Reputation='101'), Row(Id=121, Reputation='101'), Row(Id=122, Reputation='2182'), Row(Id=123, Reputation='101'), Row(Id=124, Reputation='101'), Row(Id=125, Reputation='1'), Row(Id=126, Reputation='101'), Row(Id=127, Reputation='186'), Row(Id=128, Reputation='101'), Row(Id=129, Reputation='101'), Row(Id=130, Reputation='1'), Row(Id=131, Reputation='113'), Row(Id=132, Reputation='201'), Row(Id=133, Reputation='849'), Row(Id=134, Reputation='295'), Row(Id=135, Reputation='101'), Row(Id=136, Reputation='683'), Row(Id=137, Reputation='101'), Row(Id=138, Reputation='101'), Row(Id ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# Id=107649, Reputation='1'), Row(Id=107650, Reputation='101'), Row(Id=107651, Reputation='1'), Row(Id=107652, Reputation='1'), Row(Id=107653, Reputation='1'), Row(Id=107654, Reputation='101'), Row(Id=107655, Reputation='1'), Row(Id=107656, Reputation='101'), Row(Id=107657, Reputation='1'), Row(Id=107658, Reputation='3'), Row(Id=107659, Reputation='1'), Row(Id=107660, Reputation='11'), Row(Id=107661, Reputation='11'), Row(Id=107662, Reputation='1'), Row(Id=107663, Reputation='1'), Row(Id=107664, Reputation='1'), Row(Id=107665, Reputation='1'), Row(Id=107666, Reputation='1'), Row(Id=107667, Reputation='1'), Row(Id=107668, Reputation='101'), Row(Id=107669, Reputation='101'), Row(Id=107670, Reputation='1'), Row(Id=107671, Reputation='13'), Row(Id=107672, Reputation='1'), Row(Id=107673, Reputation='1'), Row(Id=107674, Reputation='1'), Row(Id=107675, Reputation='101'), Row(Id=107676, Reputation='1'), Row(Id=107677, Reputation='1'), Row(Id=107678, Reputation='1'), Row(Id=107679, Reputation='101'), Row(Id=107680, Reputation='1'), Row(Id=107681, Reputation='1'), Row(Id=107682, Reputation='1'), Row(Id=107683, Reputation='101'), Row(Id=107684, Reputation='101'), Row(Id=107685, Reputation='101'), Row(Id=107686, Reputation='101'), Row(Id=107687, Reputation='13'), Row(Id=107688, Reputation='1'), Row(Id=107689, Reputation='1'), Row(Id=107690, Reputation='1'), Row(Id=107691, Reputation='186'), Row(Id=107692, Reputation='1'), Row(Id=107693, Reputation='1'), Row(Id=107694, Reputation='1'), Row(Id=107695, Reputation='1'), Row(Id=107696, Reputation='1'), Row(Id=107697, Reputation='1'), Row(Id=107698, Reputation='1'), Row(Id=107699, Reputation='1'), Row(Id=107700, Reputation='1'), Row(Id=107701, Reputation='1'), Row(Id=107702, Reputation='1'), Row(Id=107703, Reputation='101'), Row(Id=107704, Reputation='1'), Row(Id=107705, Reputation='1'), Row(Id=107706, Reputation='1'), Row(Id=107707, Reputation='1'), Row(Id=107708, Reputation='1'), Row(Id=107709, Reputation='101'), Row(Id=107710, Reputation='1'), Row(Id=107711, Reputation='1'), Row(Id=107712, Reputation='1'), Row(Id=107713, Reputation='1'), Row(Id=107714, Reputation='101'), Row(Id=107715, Reputation='1'), Row(Id=107716, Reputation='1'), Row(Id=107717, Reputation='1'), Row(Id=107718, Reputation='1'), Row(Id=107719, Reputation='101'), Row(Id=107720, Reputation='1'), Row(Id=107721, Reputation='101'), Row(Id=107722, Reputation='1'), Row(Id=107723, Reputation='11'), Row(Id=107724, Reputation='101'), Row(Id=107725, Reputation='11'), Row(Id=107726, Reputation='101'), Row(Id=107727, Reputation='1'), Row(Id=107728, Reputation='1'), Row(Id=107729, Reputation='1'), Row(Id=107730, Reputation='1'), Row(Id=107731, Reputation='101'), Row(Id=107732, Reputation='1'), Row(Id=107733, Reputation='1'), Row(Id=107734, Reputation='1'), Row(Id=107735, Reputation='101'), Row(Id=107736, Reputation='1'), Row(Id=107737, Reputation='103'), Row(Id=107738, Reputation='1'), Row(Id=107739, Reputation='1'), Row(Id=107740, Reputation='1'), Row(Id=107741, Reputation='1'), Row(Id=107742, Reputation='1'), Row(Id=107743, Reputation='1'), Row(Id=107744, Reputation='101'), Row(Id=107745, Reputation='1'), Row(Id=107746, Reputation='1'), Row(Id=107747, Reputation='1'), Row(Id=107748, Reputation='1'), Row(Id=107749, Reputation='1'), Row(Id=107750, Reputation='1'), Row(Id=107751, Reputation='1'), Row(Id=107752, Reputation='1'), Row(Id=107753, Reputation='1'), Row(Id=107754, Reputation='3'), Row(Id=107755, Reputation='1'), Row(Id=107756, Reputation='1'), Row(Id=107757, Reputation='101'), Row(Id=107758, Reputation='1'), Row(Id=107759, Reputation='1'), Row(Id=107760, Reputation='25'), Row(Id=107761, Reputation='1'), Row(Id=107762, Reputation='101'), Row(Id=107763, Reputation='1'), Row(Id=107764, Reputation='101'), Row(Id=107765, Reputation='1'), Row(Id=107766, Reputation='1'), Row(Id=107767, Reputation='1'), Row(Id=107768, Reputation='1'), Row(Id=107769, Reputation='101'), Row(Id=107770, Reputation='1'), Row(Id=107771, Reputation='1'), Row(Id= ...

# %% [markdown]
# ##### User expertise

# %%
## Divide the needed data into a user expertise variable
posts_df.createOrReplaceTempView("posts1")
posts_df.createOrReplaceTempView("posts2")
query2 = '''
SELECT posts1.OwnerUserId, collect_list(posts2.Tags) AS Tags
FROM posts1
INNER JOIN posts2 ON posts1.ParentId = posts2.Id
WHERE posts1.PostTypeId = 2
GROUP BY posts1.OwnerUserId
'''
usr_exp = spark.sql(query2)
print(usr_exp.collect())
# Out:
# [Row(OwnerUserId=None, Tags=['<bigdata><scalability><efficiency><performance>', '<data-mining><clustering><octave><k-means><categorical-data>', '<machine-learning><data-mining><python><classification>', '<classification><binary><svm><random-forest><logistic-regression>', '<bigdata><scalability><distributed>', '<algorithms>', '<classification>', '<machine-learning><data-mining><r><logistic-regression><gradient-descent>', '<machine-learning><python><neural-network>', '<classification><svm>', '<classification><svm>', '<machine-learning><classification><svm><accuracy><random-forest>', '<python><tools><version-control>', '<machine-learning><time-series>', '<machine-learning><statistics><career>', '<apache-hadoop><map-reduce>', '<classification><cross-validation>', '<machine-learning><online-learning>', '<dataset>', '<python><nlp><sentiment-analysis>', '<topic-model><lda>', '<bigdata><beginner>', '<bigdata><databases><binary><version-control>', '<neural-network><image-classification><preprocessing><convnet>', '<data-mining><clustering>', '<statistics>', '<machine-learning><nlp><svm><libsvm>', '<data-mining><nlp><information-retrieval><language-model>', '<text-mining><topic-model>', '<machine-learning><dataset>', '<machine-learning><r><similarity><correlation>', '<machine-learning><statistics>', '<nlp><data-formats>', '<nlp><word-embeddings>', '<algorithms><graphs><apache-spark><parallel>', '<python><topic-model><lda>', '<machine-learning><bigdata><algorithms><decision-trees>', '<machine-learning><classification><decision-trees><algorithms><pac-learning>', '<classification>', '<bigdata><software-recommendation>', '<topic-model><lda>', '<nlp>', '<statistics><data>', '<r><python><optimization>', '<bigdata><scalability>', '<machine-learning><multiclass-classification>', '<classification>', '<r><python><visualization><categorical-data><tableau>', '<svm><performance><multiclass-classification>', '<nlp><word-embeddings>', '<predictive-modeling><time-series>', '<knowledge-base>', '<nlp><text-mining>', '<data-cleaning><preprocessing>', '<machine-learning><data-mining>', '<similarity><information-retrieval>', '<machine-learning><data-mining><supervised-learning><unsupervised-learning>', '<predictive-modeling><correlation><naive-bayes-classifier>', '<text-mining><data-cleaning><data-wrangling>', '<data-mining><dataset><statistics><text-mining>', '<machine-learning><data-mining><decision-trees>', '<neural-network>', '<machine-learning><terminology><definitions><finite-precision>', '<classification><python><scikit-learn><correlation>', '<python><random-forest><scikit-learn>', '<data-mining><preprocessing>', '<python><software-recommendation><multilabel-classification>', '<random-forest><feature-selection><scikit-learn>', '<neural-network><deep-learning>', '<r>', '<machine-learning><classification>', '<machine-learning><feature-engineering>', '<ipython><jupyter>', '<classification><nlp>', '<python><deep-learning><neural-network><keras><convolutional-neural-network>', '<text-mining><topic-model>', '<machine-learning><nlp><topic-model><lda><named-entity-recognition>', '<keras>', '<topic-model><lda>', '<machine-learning><deep-learning><keras>', '<machine-learning><terminology>', '<machine-learning><python><csv><json><dataframe>', '<machine-learning><python><bigdata>', '<ibm-watson><speech-to-text>', '<r><dataframe>', '<machine-learning><classification><deep-learning><class-imbalance><bayes-error>', '<statistics><visualization><anomaly-detection><outlier><anomaly>', '<machine-learning><data-mining><anomaly-detection><outlier>', '<python><pandas>', '<machine-learning><k-means>', '<neural-network><regularization><mini-batch-gradient-descent>', '<machine-learning><random-forest><sampling><class-imbalance>', '<neural-network><optimization>', '<plotting><seaborn>', '<machine-learning><data-mining><clustering><dataset>', '<machine-learning><neural-network>', '<python><apache-spark><pyspark>', '<machine-learning><deep-learning><cnn><computer-vision><object- ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# stm><multiclass-classification>']), Row(OwnerUserId=111325, Tags=['<python><pandas>']), Row(OwnerUserId=111331, Tags=['<machine-learning>']), Row(OwnerUserId=111414, Tags=['<python><nlp><python-3.x><stemming>']), Row(OwnerUserId=111423, Tags=['<supervised-learning>', '<time-series><regression><dataset>', '<machine-learning>', '<tensorflow>', '<deep-learning><nlp><lstm><sentiment-analysis>', '<neural-network><cross-validation><hyperparameter-tuning>', '<statistics><gan><descriptive-statistics><mutual-information>']), Row(OwnerUserId=111481, Tags=['<python><scikit-learn>']), Row(OwnerUserId=111515, Tags=['<machine-learning>']), Row(OwnerUserId=111532, Tags=['<neural-network><activation-function>']), Row(OwnerUserId=111556, Tags=['<nlp><bert>']), Row(OwnerUserId=111560, Tags=['<machine-learning><predictive-modeling>']), Row(OwnerUserId=111564, Tags=['<keras><tensorflow><multi-output>', '<keras><tensorflow><multi-output>']), Row(OwnerUserId=111593, Tags=['<nlp><tfidf>']), Row(OwnerUserId=111605, Tags=['<random-forest><decision-trees>']), Row(OwnerUserId=111608, Tags=['<machine-learning><scikit-learn><tensorflow><keras><encoding>']), Row(OwnerUserId=111610, Tags=['<regression><statistics><feature-selection><linear-regression><statsmodels>']), Row(OwnerUserId=111623, Tags=['<lightgbm>']), Row(OwnerUserId=111625, Tags=['<machine-learning><python><scikit-learn><numpy>']), Row(OwnerUserId=111658, Tags=['<deep-learning><image-classification><feature-engineering><convolution><mlops>']), Row(OwnerUserId=111725, Tags=['<machine-learning><time-series><forecasting>', '<python><scikit-learn><aws><sagemaker>', '<python><pandas>', '<python><classification><statistics><feature-selection><correlation>', '<python><pandas><missing-data>', '<machine-learning><python><classification><decision-trees>', '<statistics><anomaly-detection><similarity><gaussian>', '<churn>']), Row(OwnerUserId=111756, Tags=['<python><time-series>', '<machine-learning><data-mining><data-science-model><pattern-recognition>', '<machine-learning><neural-network><word-embeddings><nlp>']), Row(OwnerUserId=111814, Tags=['<nlp>']), Row(OwnerUserId=111817, Tags=['<python><pandas>']), Row(OwnerUserId=111838, Tags=['<pandas><dataframe>']), Row(OwnerUserId=111865, Tags=['<classification><r><svm>']), Row(OwnerUserId=111887, Tags=['<deep-learning><nlp><lstm><sentiment-analysis>', '<class-imbalance><imbalanced-learn>']), Row(OwnerUserId=111929, Tags=['<seaborn>']), Row(OwnerUserId=111961, Tags=['<feature-selection><variance>', '<classification><model-selection>', '<classification><decision-trees><classifier>', '<classification><decision-trees><classifier>', '<python><pandas><data-analysis><seaborn>', '<machine-learning><regression>']), Row(OwnerUserId=112002, Tags=['<ipython><jupyter>']), Row(OwnerUserId=112026, Tags=['<machine-learning><reinforcement-learning><q-learning><markov-process>', '<reinforcement-learning><q-learning>', '<reinforcement-learning>', '<machine-learning><statistics><class-imbalance>', '<machine-learning><reinforcement-learning>', '<deep-learning><reinforcement-learning><q-learning><convergence><generalization>', '<neural-network><time-series><regression>']), Row(OwnerUserId=112027, Tags=['<machine-learning><deep-learning><text-mining><ocr>']), Row(OwnerUserId=112030, Tags=['<tensorflow>']), Row(OwnerUserId=112045, Tags=['<deep-learning><keras><embeddings>']), Row(OwnerUserId=112053, Tags=['<neural-network><deep-learning><dataset><representation>', '<scikit-learn><regression><data><svm><prediction>', '<predictive-modeling><xgboost><categorical-data>', '<machine-learning><data-mining><data-science-model><pattern-recognition>']), Row(OwnerUserId=112136, Tags=['<python>']), Row(OwnerUserId=112144, Tags=['<machine-learning><python><data><ipython><jupyter>']), Row(OwnerUserId=112189, Tags=['<machine-learning><classification><vc-theory>']), Row(OwnerUserId=112197, Tags=['<scikit-learn><decision-trees>']), Row(OwnerUserId=112204, Tags=['<machine-learning><dataset><class-imba ...

# %%
def get_tag_diversity(tag_list: list):
    resulting_tags = set()
    for tag in tag_list:
        if "><" in tag:
            divided_tags = tag.split("><")
            resulting_tags.update(tag.strip(">").strip("<") for tag in divided_tags)
        else:
            stripped_tag = tag.strip("<>").strip()
            resulting_tags.add(stripped_tag)
    return len(resulting_tags) / 638

li = ['<algorithms>', '<definitions><parallel><distributed>', '<machine-learning><dimensionality-reduction><python>', '<feature-selection><feature-extraction><dimensionality-reduction>', '<parallel><clustering><aws>', '<efficiency><algorithms><parameter>', '<data-cleaning>', '<statistics><dataset>', '<classification><performance>', '<machine-learning><bigdata>', '<recommender-system><similarity>', '<bigdata><data-mining>', '<machine-learning><dataset><class-imbalance>', '<bigdata><statistics><efficiency><scalability>', '<classification><cross-validation>', '<machine-learning><dataset>', '<feature-selection><featurization>']

print(get_tag_diversity(li))
# Out:
# 0.04075235109717868

# %%
result = list()
for row in usr_exp.collect():
  user = row["OwnerUserId"]
  usr_tags = row["Tags"]
  interest_diversity = get_tag_diversity(usr_tags)
  result.append((user, interest_diversity))


usr_diversity = spark.createDataFrame(result, ["Id", "InterestDiversity"])
print(usr_diversity.collect())
# Out:
# [Row(Id=None, InterestDiversity=0.21473354231974923), Row(Id=9, InterestDiversity=0.009404388714733543), Row(Id=11, InterestDiversity=0.004702194357366771), Row(Id=14, InterestDiversity=0.04075235109717868), Row(Id=17, InterestDiversity=0.012539184952978056), Row(Id=21, InterestDiversity=0.2006269592476489), Row(Id=22, InterestDiversity=0.006269592476489028), Row(Id=24, InterestDiversity=0.004702194357366771), Row(Id=26, InterestDiversity=0.03761755485893417), Row(Id=34, InterestDiversity=0.004702194357366771), Row(Id=36, InterestDiversity=0.003134796238244514), Row(Id=43, InterestDiversity=0.003134796238244514), Row(Id=51, InterestDiversity=0.004702194357366771), Row(Id=52, InterestDiversity=0.001567398119122257), Row(Id=53, InterestDiversity=0.003134796238244514), Row(Id=59, InterestDiversity=0.02664576802507837), Row(Id=62, InterestDiversity=0.009404388714733543), Row(Id=64, InterestDiversity=0.003134796238244514), Row(Id=70, InterestDiversity=0.003134796238244514), Row(Id=75, InterestDiversity=0.06269592476489028), Row(Id=82, InterestDiversity=0.03761755485893417), Row(Id=84, InterestDiversity=0.034482758620689655), Row(Id=88, InterestDiversity=0.003134796238244514), Row(Id=90, InterestDiversity=0.012539184952978056), Row(Id=92, InterestDiversity=0.023510971786833857), Row(Id=97, InterestDiversity=0.06269592476489028), Row(Id=104, InterestDiversity=0.009404388714733543), Row(Id=106, InterestDiversity=0.009404388714733543), Row(Id=108, InterestDiversity=0.13322884012539185), Row(Id=113, InterestDiversity=0.004702194357366771), Row(Id=115, InterestDiversity=0.01567398119122257), Row(Id=116, InterestDiversity=0.006269592476489028), Row(Id=118, InterestDiversity=0.012539184952978056), Row(Id=119, InterestDiversity=0.012539184952978056), Row(Id=122, InterestDiversity=0.004702194357366771), Row(Id=127, InterestDiversity=0.007836990595611285), Row(Id=132, InterestDiversity=0.006269592476489028), Row(Id=154, InterestDiversity=0.001567398119122257), Row(Id=156, InterestDiversity=0.018808777429467086), Row(Id=158, InterestDiversity=0.006269592476489028), Row(Id=159, InterestDiversity=0.0109717868338558), Row(Id=160, InterestDiversity=0.006269592476489028), Row(Id=168, InterestDiversity=0.004702194357366771), Row(Id=172, InterestDiversity=0.04075235109717868), Row(Id=173, InterestDiversity=0.03134796238244514), Row(Id=178, InterestDiversity=0.03918495297805643), Row(Id=180, InterestDiversity=0.006269592476489028), Row(Id=182, InterestDiversity=0.02664576802507837), Row(Id=187, InterestDiversity=0.004702194357366771), Row(Id=192, InterestDiversity=0.0109717868338558), Row(Id=201, InterestDiversity=0.12695924764890282), Row(Id=208, InterestDiversity=0.003134796238244514), Row(Id=223, InterestDiversity=0.003134796238244514), Row(Id=227, InterestDiversity=0.006269592476489028), Row(Id=229, InterestDiversity=0.006269592476489028), Row(Id=241, InterestDiversity=0.0109717868338558), Row(Id=250, InterestDiversity=0.007836990595611285), Row(Id=262, InterestDiversity=0.006269592476489028), Row(Id=265, InterestDiversity=0.006269592476489028), Row(Id=278, InterestDiversity=0.007836990595611285), Row(Id=283, InterestDiversity=0.009404388714733543), Row(Id=289, InterestDiversity=0.01567398119122257), Row(Id=290, InterestDiversity=0.003134796238244514), Row(Id=292, InterestDiversity=0.003134796238244514), Row(Id=295, InterestDiversity=0.003134796238244514), Row(Id=303, InterestDiversity=0.19435736677115986), Row(Id=322, InterestDiversity=0.007836990595611285), Row(Id=325, InterestDiversity=0.006269592476489028), Row(Id=358, InterestDiversity=0.0109717868338558), Row(Id=375, InterestDiversity=0.01567398119122257), Row(Id=378, InterestDiversity=0.017241379310344827), Row(Id=381, InterestDiversity=0.21003134796238246), Row(Id=386, InterestDiversity=0.001567398119122257), Row(Id=387, InterestDiversity=0.006269592476489028), Row(Id=389, InterestDiversity=0.014106583072100314), Row(Id=395, InterestDiversity=0.001567398119122257), Row(Id=403, InterestDive ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# d=106307, InterestDiversity=0.007836990595611285), Row(Id=106310, InterestDiversity=0.004702194357366771), Row(Id=106321, InterestDiversity=0.04231974921630094), Row(Id=106349, InterestDiversity=0.003134796238244514), Row(Id=106358, InterestDiversity=0.03761755485893417), Row(Id=106359, InterestDiversity=0.001567398119122257), Row(Id=106381, InterestDiversity=0.004702194357366771), Row(Id=106384, InterestDiversity=0.007836990595611285), Row(Id=106412, InterestDiversity=0.003134796238244514), Row(Id=106414, InterestDiversity=0.007836990595611285), Row(Id=106428, InterestDiversity=0.001567398119122257), Row(Id=106435, InterestDiversity=0.001567398119122257), Row(Id=106477, InterestDiversity=0.001567398119122257), Row(Id=106499, InterestDiversity=0.006269592476489028), Row(Id=106540, InterestDiversity=0.003134796238244514), Row(Id=106563, InterestDiversity=0.004702194357366771), Row(Id=106576, InterestDiversity=0.006269592476489028), Row(Id=106595, InterestDiversity=0.007836990595611285), Row(Id=106601, InterestDiversity=0.003134796238244514), Row(Id=106609, InterestDiversity=0.004702194357366771), Row(Id=106668, InterestDiversity=0.006269592476489028), Row(Id=106702, InterestDiversity=0.007836990595611285), Row(Id=106706, InterestDiversity=0.007836990595611285), Row(Id=106725, InterestDiversity=0.006269592476489028), Row(Id=106729, InterestDiversity=0.004702194357366771), Row(Id=106732, InterestDiversity=0.11128526645768025), Row(Id=106789, InterestDiversity=0.004702194357366771), Row(Id=106813, InterestDiversity=0.007836990595611285), Row(Id=106816, InterestDiversity=0.001567398119122257), Row(Id=106836, InterestDiversity=0.003134796238244514), Row(Id=106851, InterestDiversity=0.004702194357366771), Row(Id=106884, InterestDiversity=0.018808777429467086), Row(Id=106885, InterestDiversity=0.003134796238244514), Row(Id=106936, InterestDiversity=0.007836990595611285), Row(Id=106939, InterestDiversity=0.003134796238244514), Row(Id=106941, InterestDiversity=0.003134796238244514), Row(Id=106969, InterestDiversity=0.009404388714733543), Row(Id=106974, InterestDiversity=0.001567398119122257), Row(Id=107002, InterestDiversity=0.004702194357366771), Row(Id=107004, InterestDiversity=0.04231974921630094), Row(Id=107008, InterestDiversity=0.001567398119122257), Row(Id=107014, InterestDiversity=0.007836990595611285), Row(Id=107036, InterestDiversity=0.004702194357366771), Row(Id=107111, InterestDiversity=0.001567398119122257), Row(Id=107170, InterestDiversity=0.012539184952978056), Row(Id=107175, InterestDiversity=0.004702194357366771), Row(Id=107201, InterestDiversity=0.004702194357366771), Row(Id=107202, InterestDiversity=0.007836990595611285), Row(Id=107215, InterestDiversity=0.004702194357366771), Row(Id=107231, InterestDiversity=0.007836990595611285), Row(Id=107242, InterestDiversity=0.003134796238244514), Row(Id=107270, InterestDiversity=0.004702194357366771), Row(Id=107315, InterestDiversity=0.004702194357366771), Row(Id=107318, InterestDiversity=0.006269592476489028), Row(Id=107339, InterestDiversity=0.014106583072100314), Row(Id=107363, InterestDiversity=0.004702194357366771), Row(Id=107365, InterestDiversity=0.001567398119122257), Row(Id=107412, InterestDiversity=0.006269592476489028), Row(Id=107419, InterestDiversity=0.006269592476489028), Row(Id=107476, InterestDiversity=0.001567398119122257), Row(Id=107499, InterestDiversity=0.006269592476489028), Row(Id=107506, InterestDiversity=0.006269592476489028), Row(Id=107507, InterestDiversity=0.06426332288401254), Row(Id=107540, InterestDiversity=0.003134796238244514), Row(Id=107580, InterestDiversity=0.004702194357366771), Row(Id=107589, InterestDiversity=0.006269592476489028), Row(Id=107619, InterestDiversity=0.0109717868338558), Row(Id=107644, InterestDiversity=0.001567398119122257), Row(Id=107671, InterestDiversity=0.001567398119122257), Row(Id=107691, InterestDiversity=0.07523510971786834), Row(Id=107700, InterestDiversity=0.001567398119122257), Row(Id=107761, InterestDiversity=0.00 ...

# %% [markdown]
# ##### Create joint dataframe

# %%
usr_rep.createOrReplaceTempView("usr_rep")
usr_diversity.createOrReplaceTempView("usr_div")

query3 = '''
SELECT usr_div.Id, usr_rep.Reputation, usr_div.InterestDiversity
FROM usr_rep INNER JOIN usr_div ON usr_div.Id = usr_rep.Id
'''
final_df = spark.sql(query3)

print(final_df.collect())
# Out:
# [Row(Id=9, Reputation='1102', InterestDiversity=0.009404388714733543), Row(Id=11, Reputation='213', InterestDiversity=0.004702194357366771), Row(Id=14, Reputation='2782', InterestDiversity=0.04075235109717868), Row(Id=17, Reputation='236', InterestDiversity=0.012539184952978056), Row(Id=21, Reputation='5904', InterestDiversity=0.2006269592476489), Row(Id=22, Reputation='323', InterestDiversity=0.006269592476489028), Row(Id=24, Reputation='171', InterestDiversity=0.004702194357366771), Row(Id=26, Reputation='2952', InterestDiversity=0.03761755485893417), Row(Id=34, Reputation='173', InterestDiversity=0.004702194357366771), Row(Id=36, Reputation='325', InterestDiversity=0.003134796238244514), Row(Id=43, Reputation='101', InterestDiversity=0.003134796238244514), Row(Id=51, Reputation='176', InterestDiversity=0.004702194357366771), Row(Id=52, Reputation='146', InterestDiversity=0.001567398119122257), Row(Id=53, Reputation='404', InterestDiversity=0.003134796238244514), Row(Id=59, Reputation='986', InterestDiversity=0.02664576802507837), Row(Id=62, Reputation='654', InterestDiversity=0.009404388714733543), Row(Id=64, Reputation='75', InterestDiversity=0.003134796238244514), Row(Id=70, Reputation='181', InterestDiversity=0.003134796238244514), Row(Id=75, Reputation='721', InterestDiversity=0.06269592476489028), Row(Id=82, Reputation='549', InterestDiversity=0.03761755485893417), Row(Id=84, Reputation='3967', InterestDiversity=0.034482758620689655), Row(Id=88, Reputation='971', InterestDiversity=0.003134796238244514), Row(Id=90, Reputation='390', InterestDiversity=0.012539184952978056), Row(Id=92, Reputation='941', InterestDiversity=0.023510971786833857), Row(Id=97, Reputation='4832', InterestDiversity=0.06269592476489028), Row(Id=104, Reputation='259', InterestDiversity=0.009404388714733543), Row(Id=106, Reputation='190', InterestDiversity=0.009404388714733543), Row(Id=108, Reputation='3805', InterestDiversity=0.13322884012539185), Row(Id=113, Reputation='443', InterestDiversity=0.004702194357366771), Row(Id=115, Reputation='579', InterestDiversity=0.01567398119122257), Row(Id=116, Reputation='367', InterestDiversity=0.006269592476489028), Row(Id=118, Reputation='634', InterestDiversity=0.012539184952978056), Row(Id=119, Reputation='281', InterestDiversity=0.012539184952978056), Row(Id=122, Reputation='2182', InterestDiversity=0.004702194357366771), Row(Id=127, Reputation='186', InterestDiversity=0.007836990595611285), Row(Id=132, Reputation='201', InterestDiversity=0.006269592476489028), Row(Id=154, Reputation='636', InterestDiversity=0.001567398119122257), Row(Id=156, Reputation='390', InterestDiversity=0.018808777429467086), Row(Id=158, Reputation='1852', InterestDiversity=0.006269592476489028), Row(Id=159, Reputation='141', InterestDiversity=0.0109717868338558), Row(Id=160, Reputation='101', InterestDiversity=0.006269592476489028), Row(Id=168, Reputation='161', InterestDiversity=0.004702194357366771), Row(Id=172, Reputation='1446', InterestDiversity=0.04075235109717868), Row(Id=173, Reputation='886', InterestDiversity=0.03134796238244514), Row(Id=178, Reputation='1130', InterestDiversity=0.03918495297805643), Row(Id=180, Reputation='216', InterestDiversity=0.006269592476489028), Row(Id=182, Reputation='661', InterestDiversity=0.02664576802507837), Row(Id=187, Reputation='101', InterestDiversity=0.004702194357366771), Row(Id=192, Reputation='393', InterestDiversity=0.0109717868338558), Row(Id=201, Reputation='3210', InterestDiversity=0.12695924764890282), Row(Id=208, Reputation='111', InterestDiversity=0.003134796238244514), Row(Id=223, Reputation='101', InterestDiversity=0.003134796238244514), Row(Id=227, Reputation='1373', InterestDiversity=0.006269592476489028), Row(Id=229, Reputation='287', InterestDiversity=0.006269592476489028), Row(Id=241, Reputation='221', InterestDiversity=0.0109717868338558), Row(Id=250, Reputation='861', InterestDiversity=0.007836990595611285), Row(Id=262, Reputation='221', InterestDiversity=0.00626959 ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# InterestDiversity=0.004702194357366771), Row(Id=100633, Reputation='1', InterestDiversity=0.007836990595611285), Row(Id=100642, Reputation='21', InterestDiversity=0.003134796238244514), Row(Id=100645, Reputation='11', InterestDiversity=0.003134796238244514), Row(Id=100704, Reputation='101', InterestDiversity=0.004702194357366771), Row(Id=100734, Reputation='21', InterestDiversity=0.003134796238244514), Row(Id=100745, Reputation='1', InterestDiversity=0.012539184952978056), Row(Id=100754, Reputation='1', InterestDiversity=0.006269592476489028), Row(Id=100782, Reputation='94', InterestDiversity=0.018808777429467086), Row(Id=100802, Reputation='101', InterestDiversity=0.004702194357366771), Row(Id=100841, Reputation='11', InterestDiversity=0.001567398119122257), Row(Id=100853, Reputation='1', InterestDiversity=0.006269592476489028), Row(Id=100866, Reputation='23', InterestDiversity=0.006269592476489028), Row(Id=100874, Reputation='1', InterestDiversity=0.006269592476489028), Row(Id=100905, Reputation='150', InterestDiversity=0.017241379310344827), Row(Id=100916, Reputation='1', InterestDiversity=0.003134796238244514), Row(Id=100928, Reputation='11', InterestDiversity=0.003134796238244514), Row(Id=100936, Reputation='121', InterestDiversity=0.001567398119122257), Row(Id=100967, Reputation='130', InterestDiversity=0.0109717868338558), Row(Id=100985, Reputation='1', InterestDiversity=0.012539184952978056), Row(Id=100988, Reputation='111', InterestDiversity=0.004702194357366771), Row(Id=101057, Reputation='21', InterestDiversity=0.004702194357366771), Row(Id=101081, Reputation='101', InterestDiversity=0.006269592476489028), Row(Id=101122, Reputation='101', InterestDiversity=0.004702194357366771), Row(Id=101128, Reputation='26', InterestDiversity=0.007836990595611285), Row(Id=101174, Reputation='1', InterestDiversity=0.006269592476489028), Row(Id=101184, Reputation='101', InterestDiversity=0.004702194357366771), Row(Id=101203, Reputation='111', InterestDiversity=0.012539184952978056), Row(Id=101221, Reputation='1', InterestDiversity=0.006269592476489028), Row(Id=101245, Reputation='1', InterestDiversity=0.003134796238244514), Row(Id=101250, Reputation='1', InterestDiversity=0.004702194357366771), Row(Id=101251, Reputation='61', InterestDiversity=0.014106583072100314), Row(Id=101259, Reputation='1', InterestDiversity=0.004702194357366771), Row(Id=101276, Reputation='1', InterestDiversity=0.004702194357366771), Row(Id=101300, Reputation='89', InterestDiversity=0.007836990595611285), Row(Id=101318, Reputation='57', InterestDiversity=0.007836990595611285), Row(Id=101323, Reputation='11', InterestDiversity=0.003134796238244514), Row(Id=101337, Reputation='365', InterestDiversity=0.023510971786833857), Row(Id=101341, Reputation='121', InterestDiversity=0.007836990595611285), Row(Id=101354, Reputation='1', InterestDiversity=0.001567398119122257), Row(Id=101372, Reputation='1', InterestDiversity=0.007836990595611285), Row(Id=101375, Reputation='44', InterestDiversity=0.001567398119122257), Row(Id=101393, Reputation='1', InterestDiversity=0.006269592476489028), Row(Id=101405, Reputation='101', InterestDiversity=0.02664576802507837), Row(Id=101502, Reputation='1', InterestDiversity=0.003134796238244514), Row(Id=101552, Reputation='1', InterestDiversity=0.004702194357366771), Row(Id=101580, Reputation='454', InterestDiversity=0.0768025078369906), Row(Id=102619, Reputation='1', InterestDiversity=0.004702194357366771), Row(Id=102688, Reputation='16', InterestDiversity=0.007836990595611285), Row(Id=102715, Reputation='1', InterestDiversity=0.006269592476489028), Row(Id=102727, Reputation='111', InterestDiversity=0.003134796238244514), Row(Id=102768, Reputation='151', InterestDiversity=0.04231974921630094), Row(Id=102799, Reputation='11', InterestDiversity=0.003134796238244514), Row(Id=102819, Reputation='1', InterestDiversity=0.004702194357366771), Row(Id=102829, Reputation='1', InterestDiversity=0.004702194357366771), Row(Id=102830, Reputation='1' ...

# %% [markdown]
# ##### Correlation function

# %%
def compute_pearsons_r(df: "a DataFrame", col1: "name of column A", col2: "name of column B") -> float:
    df.createOrReplaceTempView("df")
    correlation_coefficient = spark.sql(
        f"SELECT corr({col1}, {col2}) AS correlation FROM df"
    ).first()["correlation"]
    return correlation_coefficient

# %%
print(compute_pearsons_r(final_df, "Reputation","InterestDiversity"))
# Out:
# 0.7217677648622973

# %% [markdown]
# #### Do expert users have specific interests, or do they have general interests? Kindly explain your thought process and rationale behind arriving at your answer

# %% [markdown]
# - Expert users likely have general interests. The Pearson correlation coefficient of 0.72 between Reputation points and Interest Diversity scores suggests a strong positive linear relationship. This indicates that as users gain more reputation points (indicating expertise), they also tend to have higher interest diversity scores, implying a broad range of interests rather than specific ones.
